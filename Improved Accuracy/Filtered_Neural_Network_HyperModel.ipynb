# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, Input, LeakyReLU
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from keras_tuner import HyperModel, RandomSearch

# %%
# Load the dataset
file_path = 'Total_Crops.csv'
data = pd.read_csv(file_path)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85260 entries, 0 to 85259
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   mandiid          85260 non-null  int64
#  1   cropid           85260 non-null  int64
#  2   cropname         85260 non-null  object
#  3   mandiname        85260 non-null  object
#  4   arrivalquantity  85260 non-null  int64
#  5   maximumprice     85260 non-null  int64
#  6   minimumprice     85260 non-null  int64
#  7   modalprice       85260 non-null  int64
#  8   date             85260 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 5.9+ MB

# %%
# Ensure the dataset contains 'cropid' and 'mandiid' columns
if 'cropid' in data.columns and 'mandiid' in data.columns:
    # Get the count of entries for each combination of 'cropid' and 'mandiid'
    combination_counts = data.groupby(['cropid', 'mandiid']).size().reset_index(name='count')

    # Sort the combinations by count in descending order
    combination_counts_sorted = combination_counts.sort_values(by='count', ascending=False)

    # Get the top 10 unique entries based on the counts
    top_10_unique_combinations = combination_counts_sorted.head(10)

    # Print the top 10 unique combinations without indexes
    print(top_10_unique_combinations.to_string(index=False))
else:
    print("The dataset does not contain the required 'cropid' and 'mandiid' columns.")
# Out:
#  cropid  mandiid  count
#       7      227    986
#      13      359    959
#       7      981    934
#       1     1122    926
#       1     1129    902
#       1     1142    902
#       7     1331    877
#       1     1235    863
#      13      167    859
#       1     1212    859

# %%
# Prompt for cropid and mandiid
cropid = int(input("Enter cropid: "))
mandiid_input = input("Enter mandiid (leave blank for all mandis): ")
# Out:
# Enter cropid:  1
# Enter mandiid (leave blank for all mandis):  1129

# %%
# Filter data based on inputs
if mandiid_input.strip() == "":
    filtered_data = data[data['cropid'] == cropid]
else:
    mandiid = int(mandiid_input)
    filtered_data = data[(data['cropid'] == cropid) & (data['mandiid'] == mandiid)]

# %%
filtered_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 902 entries, 5 to 85237
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   mandiid          902 non-null    int64
#  1   cropid           902 non-null    int64
#  2   cropname         902 non-null    object
#  3   mandiname        902 non-null    object
#  4   arrivalquantity  902 non-null    int64
#  5   maximumprice     902 non-null    int64
#  6   minimumprice     902 non-null    int64
#  7   modalprice       902 non-null    int64
#  8   date             902 non-null    object
# dtypes: int64(6), object(3)
# memory usage: 70.5+ KB

# %%
# Remove outliers using Z-score method
z_scores = np.abs(stats.zscore(filtered_data['modalprice']))
filtered_data = filtered_data[z_scores < 1]
print(f"Data size after removing outliers: {filtered_data.shape}")
# Out:
# Data size after removing outliers: (566, 9)

# %%
# Check if filtered data is not empty
if filtered_data.empty:
    print("No data found for the given cropid and mandiid.")
else:
    cropname = filtered_data['cropname'].iloc[0]
    mandiname = filtered_data['mandiname'].iloc[0] if mandiid_input.strip() != "" else "All Mandis"

    # Prepare data for training
    dataset = filtered_data['modalprice'].values  # Assuming 'modalprice' is the target variable
    dataset = dataset.astype('float32')
    dataset = np.reshape(dataset, (-1, 1))

    # Normalize the dataset
    scaler = MinMaxScaler(feature_range=(0, 1))
    dataset = scaler.fit_transform(dataset)

    # Split into train and test sets (80% training, 20% testing)
    train_size = int(len(dataset) * 0.8)
    train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

    # Create a dataset function
    def create_dataset(dataset, look_back=1):
        dataX, dataY = [], []
        for i in range(len(dataset) - look_back - 1):
            a = dataset[i:(i + look_back), 0]
            dataX.append(a)
            dataY.append(dataset[i + look_back, 0])
        return np.array(dataX), np.array(dataY)

    look_back = 5  # Increase look_back to consider more past days
    trainX, trainY = create_dataset(train, look_back)
    testX, testY = create_dataset(test, look_back)

    # Reshape input to be [samples, time steps, features]
    trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
    testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
class MyHyperModel(HyperModel):
    def build(self, hp):
        model = Sequential()
        model.add(Input(shape=(1, look_back)))

        # Tune the number of units in the LSTM layers
        for i in range(hp.Int('num_layers', 1, 3)):
            model.add(LSTM(units=hp.Int('units_' + str(i), min_value=50, max_value=200, step=50), return_sequences=(i < 2)))
            model.add(LeakyReLU(negative_slope=0.01))
            model.add(Dropout(rate=hp.Float('dropout_' + str(i), min_value=0.2, max_value=0.5, step=0.1)))

        model.add(Dense(1))
        
        # Tune the learning rate for the optimizer
        model.compile(optimizer=Adam(learning_rate=hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='LOG')),
                      loss='mean_squared_error')
        return model

# Instantiate the hypermodel
hypermodel = MyHyperModel()

# Instantiate the tuner and perform hyperparameter tuning
tuner = RandomSearch(
    hypermodel,
    objective='val_loss',
    max_trials=20,
    executions_per_trial=3,
    directory='my_dir',
    project_name='lstm_tuning'
)

early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

tuner.search(trainX, trainY, epochs=200, batch_size=64, validation_split=0.1, callbacks=[early_stopping], verbose=2)

# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The optimal number of layers is {best_hps.get('num_layers')}.
The optimal number of units in each layer are:
{[best_hps.get('units_' + str(i)) for i in range(best_hps.get('num_layers'))]}.
The optimal dropout rates are:
{[best_hps.get('dropout_' + str(i)) for i in range(best_hps.get('num_layers'))]}.
The optimal learning rate is {best_hps.get('learning_rate')}.
""")

# Build the model with the optimal hyperparameters and train it
model = tuner.hypermodel.build(best_hps)
model.fit(trainX, trainY, epochs=300, batch_size=32, validation_split=0.1, callbacks=[early_stopping], verbose=2)
# Out:
# Reloading Tuner from my_dir\lstm_tuning\tuner0.json
#
# The optimal number of layers is 3.
# The optimal number of units in each layer are:
# [50, 50, 150].
# The optimal dropout rates are:
# [0.30000000000000004, 0.30000000000000004, 0.4].
# The optimal learning rate is 0.004591848176101869.
#
# Epoch 1/300
# 13/13 - 14s - 1s/step - loss: 0.1725 - val_loss: 0.0865
# Epoch 2/300
# 13/13 - 0s - 19ms/step - loss: 0.0745 - val_loss: 0.0805
# Epoch 3/300
# 13/13 - 0s - 13ms/step - loss: 0.0694 - val_loss: 0.0592
# Epoch 4/300
# 13/13 - 0s - 13ms/step - loss: 0.0624 - val_loss: 0.0537
# Epoch 5/300
# 13/13 - 0s - 18ms/step - loss: 0.0544 - val_loss: 0.0370
# Epoch 6/300
# 13/13 - 0s - 13ms/step - loss: 0.0550 - val_loss: 0.0443
# Epoch 7/300
# 13/13 - 0s - 21ms/step - loss: 0.0511 - val_loss: 0.0359
# Epoch 8/300
# 13/13 - 0s - 12ms/step - loss: 0.0525 - val_loss: 0.0400
# Epoch 9/300
# 13/13 - 0s - 14ms/step - loss: 0.0503 - val_loss: 0.0371
# Epoch 10/300
# 13/13 - 0s - 14ms/step - loss: 0.0492 - val_loss: 0.0374
# Epoch 11/300
# 13/13 - 0s - 11ms/step - loss: 0.0469 - val_loss: 0.0404
# Epoch 12/300
# 13/13 - 0s - 14ms/step - loss: 0.0464 - val_loss: 0.0371
# Epoch 13/300
# 13/13 - 0s - 12ms/step - loss: 0.0480 - val_loss: 0.0426
# Epoch 14/300
# 13/13 - 0s - 13ms/step - loss: 0.0503 - val_loss: 0.0461
# Epoch 15/300
# 13/13 - 0s - 9ms/step - loss: 0.0472 - val_loss: 0.0375
# Epoch 16/300
# 13/13 - 0s - 12ms/step - loss: 0.0476 - val_loss: 0.0386
# Epoch 17/300
# 13/13 - 0s - 9ms/step - loss: 0.0467 - val_loss: 0.0378
# Epoch 18/300
# 13/13 - 0s - 14ms/step - loss: 0.0471 - val_loss: 0.0382
# Epoch 19/300
# 13/13 - 0s - 14ms/step - loss: 0.0465 - val_loss: 0.0377
# Epoch 20/300
# 13/13 - 0s - 11ms/step - loss: 0.0490 - val_loss: 0.0426
# Epoch 21/300
# 13/13 - 0s - 11ms/step - loss: 0.0473 - val_loss: 0.0370
# Epoch 22/300
# 13/13 - 0s - 10ms/step - loss: 0.0499 - val_loss: 0.0437
# Epoch 23/300
# 13/13 - 0s - 13ms/step - loss: 0.0457 - val_loss: 0.0435
# Epoch 24/300
# 13/13 - 0s - 13ms/step - loss: 0.0453 - val_loss: 0.0376
# Epoch 25/300
# 13/13 - 0s - 31ms/step - loss: 0.0469 - val_loss: 0.0386
# Epoch 26/300
# 13/13 - 0s - 22ms/step - loss: 0.0455 - val_loss: 0.0411
# Epoch 27/300
# 13/13 - 0s - 26ms/step - loss: 0.0469 - val_loss: 0.0401
# Epoch 28/300
# 13/13 - 0s - 25ms/step - loss: 0.0448 - val_loss: 0.0379
# Epoch 29/300
# 13/13 - 0s - 26ms/step - loss: 0.0441 - val_loss: 0.0436
# Epoch 30/300
# 13/13 - 0s - 17ms/step - loss: 0.0454 - val_loss: 0.0364
# Epoch 31/300
# 13/13 - 0s - 33ms/step - loss: 0.0465 - val_loss: 0.0449
# Epoch 32/300
# 13/13 - 0s - 16ms/step - loss: 0.0454 - val_loss: 0.0379
# Epoch 33/300
# 13/13 - 0s - 18ms/step - loss: 0.0445 - val_loss: 0.0395
# Epoch 34/300
# 13/13 - 0s - 18ms/step - loss: 0.0442 - val_loss: 0.0368
# Epoch 35/300
# 13/13 - 0s - 19ms/step - loss: 0.0464 - val_loss: 0.0401
# Epoch 36/300
# 13/13 - 0s - 17ms/step - loss: 0.0462 - val_loss: 0.0387
# Epoch 37/300
# 13/13 - 0s - 15ms/step - loss: 0.0465 - val_loss: 0.0374
# Epoch 38/300
# 13/13 - 0s - 16ms/step - loss: 0.0476 - val_loss: 0.0422
# Epoch 39/300
# 13/13 - 0s - 25ms/step - loss: 0.0459 - val_loss: 0.0390
# Epoch 40/300
# 13/13 - 0s - 14ms/step - loss: 0.0423 - val_loss: 0.0369
# Epoch 41/300
# 13/13 - 0s - 14ms/step - loss: 0.0460 - val_loss: 0.0383
# Epoch 42/300
# 13/13 - 0s - 15ms/step - loss: 0.0461 - val_loss: 0.0375
# Epoch 43/300
# 13/13 - 0s - 14ms/step - loss: 0.0431 - val_loss: 0.0373
# Epoch 44/300
# 13/13 - 0s - 17ms/step - loss: 0.0436 - val_loss: 0.0426
# Epoch 45/300
# 13/13 - 0s - 15ms/step - loss: 0.0470 - val_loss: 0.0426
# Epoch 46/300
# 13/13 - 0s - 17ms/step - loss: 0.0455 - val_loss: 0.0357
# Epoch 47/300
# 13/13 - 0s - 17ms/step - loss: 0.0456 - val_loss: 0.0369
# Epoch 48/300
# 13/13 - 0s - 16ms/step - loss: 0.0464 - val_loss: 0.0391
# Epoch 49/300
# 13/13 - 0s - 17ms/step - loss: 0.0432 - val_loss: 0.0364
# Epoch 50/300
# 13/13 - 0s - 18ms/step - loss: 0.0442 - val_loss: 0.0373
# Epoch 51/300
# 13/13 - 0s - 16ms/step - loss: 0.0437 - val_loss: 0.0437
# Epoch 52/300
# 13/13 - 0s - 14ms/step - loss: 0.0449 - val_loss: 0.0370
# Epoch 53/300
# 13/13 - 0s - 13ms/step - loss: 0.0478 - val_loss: 0.0395
# Epoch 54/300
# 13/13 - 0s - 11ms/step - loss: 0.0422 - val_loss: 0.0381
# Epoch 55/300
# 13/13 - 0s - 13ms/step - loss: 0.0449 - val_loss: 0.0367
# Epoch 56/300
# 13/13 - 0s - 12ms/step - loss: 0.0437 - val_loss: 0.0428
# Epoch 57/300
# 13/13 - 0s - 13ms/step - loss: 0.0450 - val_loss: 0.0363
# Epoch 58/300
# 13/13 - 0s - 13ms/step - loss: 0.0430 - val_loss: 0.0422
# Epoch 59/300
# 13/13 - 0s - 10ms/step - loss: 0.0422 - val_loss: 0.0355
# Epoch 60/300
# 13/13 - 0s - 12ms/step - loss: 0.0437 - val_loss: 0.0408
# Epoch 61/300
# 13/13 - 0s - 10ms/step - loss: 0.0449 - val_loss: 0.0356
# Epoch 62/300
# 13/13 - 0s - 10ms/step - loss: 0.0441 - val_loss: 0.0379
# Epoch 63/300
# 13/13 - 0s - 11ms/step - loss: 0.0428 - val_loss: 0.0401
# Epoch 64/300
# 13/13 - 0s - 12ms/step - loss: 0.0430 - val_loss: 0.0364
# Epoch 65/300
# 13/13 - 0s - 10ms/step - loss: 0.0440 - val_loss: 0.0376
# Epoch 66/300
# 13/13 - 0s - 12ms/step - loss: 0.0433 - val_loss: 0.0351
# Epoch 67/300
# 13/13 - 0s - 14ms/step - loss: 0.0444 - val_loss: 0.0430
# Epoch 68/300
# 13/13 - 0s - 15ms/step - loss: 0.0430 - val_loss: 0.0350
# Epoch 69/300
# 13/13 - 0s - 12ms/step - loss: 0.0424 - val_loss: 0.0376
# Epoch 70/300
# 13/13 - 0s - 12ms/step - loss: 0.0417 - val_loss: 0.0381
# Epoch 71/300
# 13/13 - 0s - 13ms/step - loss: 0.0439 - val_loss: 0.0354
# Epoch 72/300
# 13/13 - 0s - 13ms/step - loss: 0.0456 - val_loss: 0.0420
# Epoch 73/300
# 13/13 - 0s - 12ms/step - loss: 0.0424 - val_loss: 0.0358
# Epoch 74/300
# 13/13 - 0s - 12ms/step - loss: 0.0440 - val_loss: 0.0476
# Epoch 75/300
# 13/13 - 0s - 14ms/step - loss: 0.0455 - val_loss: 0.0351
# Epoch 76/300
# 13/13 - 0s - 15ms/step - loss: 0.0441 - val_loss: 0.0364
# Epoch 77/300
# 13/13 - 0s - 12ms/step - loss: 0.0431 - val_loss: 0.0352
# Epoch 78/300
# 13/13 - 0s - 12ms/step - loss: 0.0423 - val_loss: 0.0355
# Epoch 79/300
# 13/13 - 0s - 11ms/step - loss: 0.0429 - val_loss: 0.0417
# Epoch 80/300
# 13/13 - 0s - 12ms/step - loss: 0.0440 - val_loss: 0.0358
# Epoch 81/300
# 13/13 - 0s - 11ms/step - loss: 0.0420 - val_loss: 0.0356
# Epoch 82/300
# 13/13 - 0s - 11ms/step - loss: 0.0429 - val_loss: 0.0353
# Epoch 83/300
# 13/13 - 0s - 12ms/step - loss: 0.0421 - val_loss: 0.0374
# Epoch 84/300
# 13/13 - 0s - 11ms/step - loss: 0.0420 - val_loss: 0.0372
# Epoch 85/300
# 13/13 - 0s - 12ms/step - loss: 0.0418 - val_loss: 0.0369
# Epoch 86/300
# 13/13 - 0s - 10ms/step - loss: 0.0428 - val_loss: 0.0346
# Epoch 87/300
# 13/13 - 0s - 13ms/step - loss: 0.0446 - val_loss: 0.0344
# Epoch 88/300
# 13/13 - 0s - 11ms/step - loss: 0.0435 - val_loss: 0.0351
# Epoch 89/300
# 13/13 - 0s - 10ms/step - loss: 0.0427 - val_loss: 0.0412
# Epoch 90/300
# 13/13 - 0s - 12ms/step - loss: 0.0426 - val_loss: 0.0341
# Epoch 91/300
# 13/13 - 0s - 10ms/step - loss: 0.0442 - val_loss: 0.0375
# Epoch 92/300
# 13/13 - 0s - 11ms/step - loss: 0.0427 - val_loss: 0.0356
# Epoch 93/300
# 13/13 - 0s - 11ms/step - loss: 0.0417 - val_loss: 0.0347
# Epoch 94/300
# 13/13 - 0s - 11ms/step - loss: 0.0429 - val_loss: 0.0382
# Epoch 95/300
# 13/13 - 0s - 9ms/step - loss: 0.0423 - val_loss: 0.0345
# Epoch 96/300
# 13/13 - 0s - 10ms/step - loss: 0.0431 - val_loss: 0.0357
# Epoch 97/300
# 13/13 - 0s - 10ms/step - loss: 0.0445 - val_loss: 0.0357
# Epoch 98/300
# 13/13 - 0s - 10ms/step - loss: 0.0439 - val_loss: 0.0370
# Epoch 99/300
# 13/13 - 0s - 9ms/step - loss: 0.0428 - val_loss: 0.0373
# Epoch 100/300
# 13/13 - 0s - 9ms/step - loss: 0.0421 - val_loss: 0.0343
# Epoch 101/300
# 13/13 - 0s - 9ms/step - loss: 0.0441 - val_loss: 0.0360
# Epoch 102/300
# 13/13 - 0s - 14ms/step - loss: 0.0428 - val_loss: 0.0403
# Epoch 103/300
# 13/13 - 0s - 10ms/step - loss: 0.0428 - val_loss: 0.0345
# Epoch 104/300
# 13/13 - 0s - 17ms/step - loss: 0.0433 - val_loss: 0.0378
# Epoch 105/300
# 13/13 - 0s - 12ms/step - loss: 0.0419 - val_loss: 0.0362
# Epoch 106/300
# 13/13 - 0s - 10ms/step - loss: 0.0427 - val_loss: 0.0342
# Epoch 107/300
# 13/13 - 0s - 12ms/step - loss: 0.0413 - val_loss: 0.0341
# Epoch 108/300
# 13/13 - 0s - 10ms/step - loss: 0.0426 - val_loss: 0.0340
# Epoch 109/300
# 13/13 - 0s - 10ms/step - loss: 0.0418 - val_loss: 0.0358
# Epoch 110/300
# 13/13 - 0s - 9ms/step - loss: 0.0435 - val_loss: 0.0355
# Epoch 111/300
# 13/13 - 0s - 10ms/step - loss: 0.0411 - val_loss: 0.0353
# Epoch 112/300
# 13/13 - 0s - 9ms/step - loss: 0.0420 - val_loss: 0.0358
# Epoch 113/300
# 13/13 - 0s - 10ms/step - loss: 0.0415 - val_loss: 0.0350
# Epoch 114/300
# 13/13 - 0s - 9ms/step - loss: 0.0409 - val_loss: 0.0351
# Epoch 115/300
# 13/13 - 0s - 10ms/step - loss: 0.0436 - val_loss: 0.0342
# Epoch 116/300
# 13/13 - 0s - 9ms/step - loss: 0.0402 - val_loss: 0.0356
# Epoch 117/300
# 13/13 - 0s - 11ms/step - loss: 0.0401 - val_loss: 0.0336
# Epoch 118/300
# 13/13 - 0s - 12ms/step - loss: 0.0405 - val_loss: 0.0372
# Epoch 119/300
# 13/13 - 0s - 13ms/step - loss: 0.0410 - val_loss: 0.0343
# Epoch 120/300
# 13/13 - 0s - 12ms/step - loss: 0.0415 - val_loss: 0.0361
# Epoch 121/300
# 13/13 - 0s - 10ms/step - loss: 0.0417 - val_loss: 0.0355
# Epoch 122/300
# 13/13 - 0s - 10ms/step - loss: 0.0424 - val_loss: 0.0355
# Epoch 123/300
# 13/13 - 0s - 19ms/step - loss: 0.0407 - val_loss: 0.0344
# Epoch 124/300
# 13/13 - 0s - 16ms/step - loss: 0.0403 - val_loss: 0.0363
# Epoch 125/300
# 13/13 - 0s - 13ms/step - loss: 0.0432 - val_loss: 0.0342
# Epoch 126/300
# 13/13 - 0s - 14ms/step - loss: 0.0426 - val_loss: 0.0494
# Epoch 127/300
# 13/13 - 0s - 21ms/step - loss: 0.0423 - val_loss: 0.0335
# Epoch 128/300
# 13/13 - 0s - 10ms/step - loss: 0.0409 - val_loss: 0.0350
# Epoch 129/300
# 13/13 - 0s - 12ms/step - loss: 0.0410 - val_loss: 0.0344
# Epoch 130/300
# 13/13 - 0s - 12ms/step - loss: 0.0403 - val_loss: 0.0378
# Epoch 131/300
# 13/13 - 0s - 14ms/step - loss: 0.0406 - val_loss: 0.0338
# Epoch 132/300
# 13/13 - 0s - 16ms/step - loss: 0.0403 - val_loss: 0.0418
# Epoch 133/300
# 13/13 - 0s - 18ms/step - loss: 0.0419 - val_loss: 0.0331
# Epoch 134/300
# 13/13 - 0s - 15ms/step - loss: 0.0387 - val_loss: 0.0384
# Epoch 135/300
# 13/13 - 0s - 14ms/step - loss: 0.0420 - val_loss: 0.0351
# Epoch 136/300
# 13/13 - 0s - 18ms/step - loss: 0.0411 - val_loss: 0.0346
# Epoch 137/300
# 13/13 - 0s - 19ms/step - loss: 0.0403 - val_loss: 0.0337
# Epoch 138/300
# 13/13 - 0s - 14ms/step - loss: 0.0398 - val_loss: 0.0328
# Epoch 139/300
# 13/13 - 0s - 14ms/step - loss: 0.0406 - val_loss: 0.0384
# Epoch 140/300
# 13/13 - 0s - 13ms/step - loss: 0.0424 - val_loss: 0.0322
# Epoch 141/300
# 13/13 - 0s - 11ms/step - loss: 0.0392 - val_loss: 0.0328
# Epoch 142/300
# 13/13 - 0s - 10ms/step - loss: 0.0381 - val_loss: 0.0328
# Epoch 143/300
# 13/13 - 0s - 11ms/step - loss: 0.0409 - val_loss: 0.0371
# Epoch 144/300
# 13/13 - 0s - 11ms/step - loss: 0.0419 - val_loss: 0.0345
# Epoch 145/300
# 13/13 - 0s - 11ms/step - loss: 0.0421 - val_loss: 0.0355
# Epoch 146/300
# 13/13 - 0s - 12ms/step - loss: 0.0408 - val_loss: 0.0337
# Epoch 147/300
# 13/13 - 0s - 10ms/step - loss: 0.0423 - val_loss: 0.0423
# Epoch 148/300
# 13/13 - 0s - 10ms/step - loss: 0.0436 - val_loss: 0.0339
# Epoch 149/300
# 13/13 - 0s - 12ms/step - loss: 0.0408 - val_loss: 0.0408
# Epoch 150/300
# 13/13 - 0s - 10ms/step - loss: 0.0430 - val_loss: 0.0334
# Epoch 151/300
# 13/13 - 0s - 9ms/step - loss: 0.0423 - val_loss: 0.0368
# Epoch 152/300
# 13/13 - 0s - 10ms/step - loss: 0.0407 - val_loss: 0.0334
# Epoch 153/300
# 13/13 - 0s - 10ms/step - loss: 0.0433 - val_loss: 0.0395
# Epoch 154/300
# 13/13 - 0s - 9ms/step - loss: 0.0406 - val_loss: 0.0343
# Epoch 155/300
# 13/13 - 0s - 9ms/step - loss: 0.0409 - val_loss: 0.0367
# Epoch 156/300
# 13/13 - 0s - 10ms/step - loss: 0.0392 - val_loss: 0.0331
# Epoch 157/300
# 13/13 - 0s - 10ms/step - loss: 0.0398 - val_loss: 0.0340
# Epoch 158/300
# 13/13 - 0s - 9ms/step - loss: 0.0418 - val_loss: 0.0357
# Epoch 159/300
# 13/13 - 0s - 9ms/step - loss: 0.0410 - val_loss: 0.0372
# Epoch 160/300
# 13/13 - 0s - 10ms/step - loss: 0.0409 - val_loss: 0.0346
# Epoch 161/300
# 13/13 - 0s - 12ms/step - loss: 0.0414 - val_loss: 0.0378
# Epoch 162/300
# 13/13 - 0s - 9ms/step - loss: 0.0421 - val_loss: 0.0375
# Epoch 163/300
# 13/13 - 0s - 10ms/step - loss: 0.0415 - val_loss: 0.0337
# Epoch 164/300
# 13/13 - 0s - 19ms/step - loss: 0.0398 - val_loss: 0.0371
# Epoch 165/300
# 13/13 - 0s - 14ms/step - loss: 0.0387 - val_loss: 0.0342
# Epoch 166/300
# 13/13 - 0s - 11ms/step - loss: 0.0394 - val_loss: 0.0335
# Epoch 167/300
# 13/13 - 0s - 13ms/step - loss: 0.0395 - val_loss: 0.0354
# Epoch 168/300
# 13/13 - 0s - 10ms/step - loss: 0.0407 - val_loss: 0.0364
# Epoch 169/300
# 13/13 - 0s - 9ms/step - loss: 0.0401 - val_loss: 0.0361
# Epoch 170/300
# 13/13 - 0s - 10ms/step - loss: 0.0382 - val_loss: 0.0341
# Epoch 171/300
# 13/13 - 0s - 10ms/step - loss: 0.0402 - val_loss: 0.0363
# Epoch 172/300
# 13/13 - 0s - 10ms/step - loss: 0.0391 - val_loss: 0.0355
# Epoch 173/300
# 13/13 - 0s - 10ms/step - loss: 0.0405 - val_loss: 0.0353
# Epoch 174/300
# 13/13 - 0s - 16ms/step - loss: 0.0386 - val_loss: 0.0352
# Epoch 175/300
# 13/13 - 0s - 14ms/step - loss: 0.0416 - val_loss: 0.0363
# Epoch 176/300
# 13/13 - 0s - 21ms/step - loss: 0.0400 - val_loss: 0.0348
# Epoch 177/300
# 13/13 - 0s - 13ms/step - loss: 0.0404 - val_loss: 0.0386
# Epoch 178/300
# 13/13 - 0s - 24ms/step - loss: 0.0401 - val_loss: 0.0346
# Epoch 179/300
# 13/13 - 0s - 13ms/step - loss: 0.0395 - val_loss: 0.0353
# Epoch 180/300
# 13/13 - 0s - 14ms/step - loss: 0.0411 - val_loss: 0.0382
# Epoch 181/300
# 13/13 - 0s - 29ms/step - loss: 0.0395 - val_loss: 0.0347
# Epoch 182/300
# 13/13 - 0s - 19ms/step - loss: 0.0420 - val_loss: 0.0387
# Epoch 183/300
# 13/13 - 0s - 15ms/step - loss: 0.0414 - val_loss: 0.0345
# Epoch 184/300
# 13/13 - 0s - 24ms/step - loss: 0.0400 - val_loss: 0.0355
# Epoch 185/300
# 13/13 - 0s - 19ms/step - loss: 0.0391 - val_loss: 0.0371
# Epoch 186/300
# 13/13 - 0s - 17ms/step - loss: 0.0380 - val_loss: 0.0368
# Epoch 187/300
# 13/13 - 0s - 17ms/step - loss: 0.0381 - val_loss: 0.0355
# Epoch 188/300
# 13/13 - 0s - 16ms/step - loss: 0.0392 - val_loss: 0.0354
# Epoch 189/300
# 13/13 - 0s - 12ms/step - loss: 0.0402 - val_loss: 0.0378
# Epoch 190/300
# 13/13 - 0s - 12ms/step - loss: 0.0400 - val_loss: 0.0348

# %%
# Function for generating predictions
def predict_future(model, testX, days, look_back):
    predictions = []
    current_input = testX[-1]  # Start with the last input from the test set
    current_input = np.reshape(current_input, (1, 1, look_back))
    for _ in range(days):
        prediction = model.predict(current_input)
        predictions.append(prediction[0][0])
        current_input = np.append(current_input[:, :, 1:], prediction).reshape((1, 1, look_back))
    return predictions

# %%
# Prompt for number of days for prediction
days = int(input("Enter number of days to predict: "))
# Out:
# Enter number of days to predict:  10

# %%
# Generate predictions for the specified number of days
predictions = predict_future(model, testX, days, look_back)

# Inverse transform the predictions
predictions = scaler.inverse_transform(np.array(predictions).reshape(-1, 1))

# Prepare data for visualization with fixed start date
start_date = pd.to_datetime('2024-03-04')
prediction_dates = pd.date_range(start=start_date, periods=days)
prediction_series = pd.Series(predictions.flatten(), index=prediction_dates)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 894ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step

# %%
# Standalone prediction plot
plt.figure(figsize=(12, 6))
plt.plot(prediction_series, label='Predicted Prices', linestyle='--', marker='o')
for i, txt in enumerate(predictions):
    plt.annotate(f'{txt[0]:.2f}', (prediction_series.index[i], prediction_series.values[i]), textcoords="offset points", xytext=(0,10), ha='center')
plt.title(f'Standalone Prediction for {cropname} ({mandiname})\nNumber of days: {days}')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.xticks(rotation=30)
plt.grid(True)
plt.show()

# %%
# Combined plot of historical data and predictions
historical_series = pd.Series(filtered_data['modalprice'].values, index=pd.to_datetime(filtered_data['date']))
plt.figure(figsize=(15, 8))
plt.scatter(historical_series.index, historical_series.values, label='Historical Prices')
plt.plot(prediction_series, label='Predicted Prices', linestyle='', marker='^')
plt.title(f'Historical and Predicted Prices for {cropname} ({mandiname})\nNumber of days: {days}')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Convert predictions to a DataFrame
predicted_df = pd.DataFrame(predictions, columns=['predicted_price'])

# Save the predictions to a CSV file
output_path = f'Predicted_{cropname}_NeuralNetwork.csv'
predicted_df.to_csv(output_path, index=False)

print(f"Predictions saved to {output_path}")
# Out:
# Predictions saved to Predicted_Corn_NeuralNetwork.csv
